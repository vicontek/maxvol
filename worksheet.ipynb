# %%
import rect_maxvol
import numpy as np
from mnist import MNIST
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
m, k = 10000, 2200
M = np.random.rand(m, k)
M
# Out:
# array([[0.99493031, 0.35716917, 0.7018215 , ..., 0.18118692, 0.25182892,
#         0.578692  ],
#        [0.73282514, 0.60093458, 0.9850691 , ..., 0.44693332, 0.0207341 ,
#         0.78135833],
#        [0.90848968, 0.35495219, 0.13062466, ..., 0.64765527, 0.94906264,
#         0.26081042],
#        ...,
#        [0.95102464, 0.50936007, 0.61056161, ..., 0.65025207, 0.49343391,
#         0.72606582],
#        [0.61004247, 0.60077048, 0.36154722, ..., 0.53298964, 0.25615791,
#         0.13184888],
#        [0.48928931, 0.35155411, 0.34152635, ..., 0.17661539, 0.17634078,
#         0.0672175 ]])

# %%
M[rect_maxvol.rect_maxvol(M, minK=4, maxK=4)[0]]
# %time
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.77 µs

# %%
mndata = MNIST('datasets/mnist')

train_images, train_labels = mndata.load_training()
test_images, test_labels = mndata.load_testing()

X_train = mndata.process_images_to_numpy(train_images)
Y_train = np.array(train_labels)

X_test = mndata.process_images_to_numpy(test_images)
Y_test = np.array(test_labels)

# %%
plt.imshow(np.reshape(X_train[0], (28, 28)))
Y_train[0]
# Out:
# 5

# %%
x = mndata.process_images_to_numpy(images)

# %%
# Out:
# (10000, 784)
